# %% [markdown]
# trial notebook in which i simply try out some code to see how and if it works

# %%
import pickle 
from pathlib import Path
data_dir = Path('data')
with open(data_dir / 'corrective_integrated.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
column_names = data.columns.tolist()
print(column_names)
# Out:
# ['portfolio', 'id_ordre_travail', 'id_demande', 'etat', 'motif_standby', 'anomalie', 'urgence', 'impact_disponibilite', 'vandalisme', 'palliative', 'avec_demande_pdr', 'est_reouvert', 'site', 'zone', 'famille', 'groupe', 'localisation', 'actif', 'demandeur', 'ot_fils', 'date_declaration', 'createur_ot', 'date_creation_ot', 'utilisateur_prestataire', 'date_debut_reparation', 'responsable_cloture', 'date_cloture', 'commentaire_cloture', 'responsable_reouverture', 'date_reouverture', 'commentaire_ouverture', 'validateur_travaux', 'date_validation', 'responsable_rejet', 'date_rejet', 'motif_rejet', 'prestataire', 'cout_maindoeuvre', 'cout_pdr', 'cout_bc', 'cout_total', 'description', 'plateforme_creation', 'plateforme_prestataire', 'plateforme_cloture', 'plateforme_rejet', 'plateforme_reouverture', 'plateforme_validation', 'nombre_main_doeuvre', 'duree_intervention_par_heure', 'id_actif', 'time_to_closure_hours', 'time_to_start_hours', 'num_spare_parts_requests', 'total_parts_quantity', 
# ...
